# %%
# %pip install transformers
# %pip install seqeval
# Out:
# Looking in indexes: https://mirrors.sjtug.sjtu.edu.cn/pypi/web/simple
# ...
#      |████████████████████████████████| 3.4 MB 1.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 748 kB 990 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 67 kB 842 kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 895 kB 1.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.3 MB 589 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 659 kB/s eta 0:00:011
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://mirrors.sjtug.sjtu.edu.cn/pypi/web/simple
# ...
#      |████████████████████████████████| 43 kB 544 kB/s eta 0:00:011
# ...

# %%
# %run run_softmax_ner.py\
--data_dir 'task_core_aux_cond/k-fold/combine/0/'\
--model_type "bert"\
--model_name_or_path "bert-base-cased"\
--output_dir "task_core_aux_cond/model/0/"\
--labels "task_core_aux_cond/labels.txt"\
--overwrite_output_dir\
--do_train\
--do_eval\
--evaluate_during_training\
--adv_training fgm\
--num_train_epochs 8\
--max_seq_length 128\
--logging_steps 0.2\
--per_gpu_train_batch_size 16\
--per_gpu_eval_batch_size 16\
--learning_rate 5e-5\
--bert_lr 5e-5\
--classifier_lr  5e-5
# Out:
# 01/20/2022 13:44:43 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 01/20/2022 13:44:45 - INFO - __main__ -   Tokenizer arguments: {'do_lower_case': False}
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertSoftmaxForNer: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertSoftmaxForNer from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# %run run_softmax_ner.py\
--data_dir 'task_core_aux_cond/k-fold/combine/1/'\
--model_type "bert"\
--model_name_or_path "bert-base-cased"\
--output_dir "task_core_aux_cond/model/1/"\
--labels "task_core_aux_cond/labels.txt"\
--overwrite_output_dir\
--do_train\
--do_eval\
--evaluate_during_training\
--adv_training fgm\
--num_train_epochs 8\
--max_seq_length 128\
--logging_steps 0.2\
--per_gpu_train_batch_size 16\
--per_gpu_eval_batch_size 16\
--learning_rate 5e-5\
--bert_lr 5e-5\
--classifier_lr  5e-5
# Out:
# 01/20/2022 13:52:25 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 01/20/2022 13:52:27 - INFO - __main__ -   Tokenizer arguments: {'do_lower_case': False}
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertSoftmaxForNer: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertSoftmaxForNer from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# ⭐️
# %run run_softmax_ner.py\
--data_dir 'pretrained_data/task_core_aux_cond/k-fold/combine/2/'\
--model_type "bert"\
--model_name_or_path "bert-base-cased"\
--output_dir "pretrained_model/task_core_aux_cond/2/"\
--labels "pretrained_data/task_core_aux_cond/labels.txt"\
--overwrite_output_dir\
--do_train\
--do_eval\
--evaluate_during_training\
--adv_training fgm\
--num_train_epochs 8\
--max_seq_length 128\
--logging_steps 0.2\
--per_gpu_train_batch_size 16\
--per_gpu_eval_batch_size 16\
--learning_rate 5e-5\
--bert_lr 5e-5\
--classifier_lr  5e-5
# Out:
# 01/20/2022 13:59:25 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 01/20/2022 13:59:27 - INFO - __main__ -   Tokenizer arguments: {'do_lower_case': False}
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertSoftmaxForNer: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertSoftmaxForNer from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# %run run_softmax_ner.py\
--data_dir 'task_core_aux_cond/k-fold/combine/3/'\
--model_type "bert"\
--model_name_or_path "bert-base-cased"\
--output_dir "task_core_aux_cond/model/3/"\
--labels "task_core_aux_cond/labels.txt"\
--overwrite_output_dir\
--do_train\
--do_eval\
--evaluate_during_training\
--adv_training fgm\
--num_train_epochs 8\
--max_seq_length 128\
--logging_steps 0.2\
--per_gpu_train_batch_size 16\
--per_gpu_eval_batch_size 16\
--learning_rate 5e-5\
--bert_lr 5e-5\
--classifier_lr  5e-5
# Out:
# 01/20/2022 14:07:03 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 01/20/2022 14:07:06 - INFO - __main__ -   Tokenizer arguments: {'do_lower_case': False}
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertSoftmaxForNer: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertSoftmaxForNer from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# %run run_softmax_ner.py\
--data_dir 'task_core_aux_cond/k-fold/combine/4/'\
--model_type "bert"\
--model_name_or_path "bert-base-cased"\
--output_dir "task_core_aux_cond/model/4/"\
--labels "task_core_aux_cond/labels.txt"\
--overwrite_output_dir\
--do_train\
--do_eval\
--evaluate_during_training\
--adv_training fgm\
--num_train_epochs 8\
--max_seq_length 128\
--logging_steps 0.2\
--per_gpu_train_batch_size 16\
--per_gpu_eval_batch_size 16\
--learning_rate 5e-5\
--bert_lr 5e-5\
--classifier_lr  5e-5
# Out:
# 01/20/2022 14:14:34 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 01/20/2022 14:14:36 - INFO - __main__ -   Tokenizer arguments: {'do_lower_case': False}
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertSoftmaxForNer: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertSoftmaxForNer from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# %run run_crf_ner.py\
--data_dir 'task_core_aux_cond/k-fold/combine/0/'\
--model_type "bert"\
--model_name_or_path "bert-base-cased"\
--output_dir "task_core_aux_cond/model/crf_0/"\
--labels "task_core_aux_cond/labels.txt"\
--overwrite_output_dir\
--do_train\
--do_eval\
--evaluate_during_training\
--adv_training fgm\
--num_train_epochs 8\
--max_seq_length 128\
--logging_steps 0.2\
--per_gpu_train_batch_size 16\
--per_gpu_eval_batch_size 16\
--learning_rate 5e-5\
--bert_lr 5e-5\
--classifier_lr  5e-5\
--crf_lr 1e-3
# Out:
# 01/20/2022 14:41:21 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 01/20/2022 14:41:26 - INFO - __main__ -   Tokenizer arguments: {'do_lower_case': False}
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertCrfForNer: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertCrfForNer from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# %run run_crf_ner.py\
--data_dir 'task_core_aux_cond/k-fold/combine/1/'\
--model_type "bert"\
--model_name_or_path "bert-base-cased"\
--output_dir "task_core_aux_cond/model/crf_1/"\
--labels "task_core_aux_cond/labels.txt"\
--overwrite_output_dir\
--do_train\
--do_eval\
--evaluate_during_training\
--adv_training fgm\
--num_train_epochs 8\
--max_seq_length 128\
--logging_steps 0.2\
--per_gpu_train_batch_size 16\
--per_gpu_eval_batch_size 16\
--learning_rate 5e-5\
--bert_lr 5e-5\
--classifier_lr  5e-5\
--crf_lr 1e-3
# Out:
# 01/20/2022 14:50:56 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 01/20/2022 14:50:58 - INFO - __main__ -   Tokenizer arguments: {'do_lower_case': False}
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertCrfForNer: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertCrfForNer from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# %run run_crf_ner.py\
--data_dir 'task_core_aux_cond/k-fold/combine/2/'\
--model_type "bert"\
--model_name_or_path "bert-base-cased"\
--output_dir "task_core_aux_cond/model/crf_2/"\
--labels "task_core_aux_cond/labels.txt"\
--overwrite_output_dir\
--do_train\
--do_eval\
--evaluate_during_training\
--adv_training fgm\
--num_train_epochs 8\
--max_seq_length 128\
--logging_steps 0.2\
--per_gpu_train_batch_size 16\
--per_gpu_eval_batch_size 16\
--learning_rate 5e-5\
--bert_lr 5e-5\
--classifier_lr  5e-5\
--crf_lr 1e-3
# Out:
# 01/20/2022 14:59:29 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 01/20/2022 14:59:32 - INFO - __main__ -   Tokenizer arguments: {'do_lower_case': False}
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertCrfForNer: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertCrfForNer from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# %run run_crf_ner.py\
--data_dir 'task_core_aux_cond/k-fold/combine/3/'\
--model_type "bert"\
--model_name_or_path "bert-base-cased"\
--output_dir "task_core_aux_cond/model/crf_3/"\
--labels "task_core_aux_cond/labels.txt"\
--overwrite_output_dir\
--do_train\
--do_eval\
--evaluate_during_training\
--adv_training fgm\
--num_train_epochs 8\
--max_seq_length 128\
--logging_steps 0.2\
--per_gpu_train_batch_size 16\
--per_gpu_eval_batch_size 16\
--learning_rate 5e-5\
--bert_lr 5e-5\
--classifier_lr  5e-5\
--crf_lr 1e-3
# Out:
# 01/20/2022 15:08:21 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 01/20/2022 15:08:26 - INFO - __main__ -   Tokenizer arguments: {'do_lower_case': False}
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertCrfForNer: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertCrfForNer from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# %run run_crf_ner.py\
--data_dir 'task_core_aux_cond/k-fold/combine/4/'\
--model_type "bert"\
--model_name_or_path "bert-base-cased"\
--output_dir "task_core_aux_cond/model/crf_4/"\
--labels "task_core_aux_cond/labels.txt"\
--overwrite_output_dir\
--do_train\
--do_eval\
--evaluate_during_training\
--adv_training fgm\
--num_train_epochs 8\
--max_seq_length 128\
--logging_steps 0.2\
--per_gpu_train_batch_size 16\
--per_gpu_eval_batch_size 16\
--learning_rate 5e-5\
--bert_lr 5e-5\
--classifier_lr  5e-5\
--crf_lr 1e-3
# Out:
# 01/20/2022 15:17:23 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 01/20/2022 15:17:27 - INFO - __main__ -   Tokenizer arguments: {'do_lower_case': False}
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertCrfForNer: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertCrfForNer from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...
